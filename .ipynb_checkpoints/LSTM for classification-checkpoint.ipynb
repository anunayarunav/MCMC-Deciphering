# %%
# As usual, a bit of setup

import time, os, json
import numpy as np
import matplotlib.pyplot as plt

from metropolis_hastings import *
from deshuffling_utils import *
import sys  

from nn.rnn_layers import *
from nn.char_nn import *
from nn.optim import *
from nn.sequence_classifier import *
from nn.gradient_check import *

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %%
N, D, W, H1, H2 = 10, 10, 10, 10, 10
word_to_idx = {'<NULL>': 0, 'cat': 2, 'dog': 3}
V = len(word_to_idx)
T = 13

model = SequenceClassifier(input_dims=V,
          embedding_dims=W,
          lstm_layers=2,
          hidden_dims=[H1,H2],
          label_count=2,
          dtype=np.float64)

features = np.random.choice(V, (N,T))
captions = np.random.choice(2, N)

loss, grads = model.loss(features, captions)

for param_name in sorted(grads):
  f = lambda _: model.loss(features, captions)[0]
  param_grad_num = eval_numerical_gradient(f, model.params[param_name], verbose=False, h=1e-6)
  e = rel_error(param_grad_num, grads[param_name])
  print '%s relative error: %e' % (param_name, e)

# %%
def train_model(X_train, y_train, X_test, y_test, vocab_size, reg, iters=1000, print_every=50, batch_size=50):
    
    #train on the network
    V = vocab_size
    N_train = X_train.shape[0]
    N_test = X_test.shape[0]
    embedding_dims = vocab_size
    layers = 1
    hidden_dims = [100]

    model = SequenceClassifier(input_dims=V,
              embedding_dims=embedding_dims,
              lstm_layers=layers,
              hidden_dims=hidden_dims,
              label_count=2,
              reg= reg,
              dtype=np.float32)

    i = 0

    it = iters

    config = {}

    loss_trains = []
    loss_tests = []

    while i < it:
        batch_indices = np.random.choice(N_train, batch_size)
        batch_features = X_train[batch_indices, :]
        batch_labels = y_train[batch_indices]

        loss, grads = model.loss(batch_features, batch_labels)

        for name, value in grads.iteritems():
            if name not in config:
                config[name] = {'learning_rate':1e-3}

            model.params[name], config[name] = adam(model.params[name], value, config[name])

        if i%print_every == 0:
            indices = np.random.choice(N_test, batch_size)
            loss_test, _ = model.loss(X_test[indices,:], y_test[indices])
            test_accuracy = np.mean(model.predict(X_test[indices,:]) == y_test[indices])
            
            print "iter %d, loss_train %f, lost_test %f, test accuracy %f"%(i, loss, loss_test, test_accuracy)
            #print "Losses for shuffled data ,", l1, l2
            loss_trains.append(loss)
            loss_tests.append(loss_test)

        i += 1

    plt.plot(loss_trains)
    plt.plot(loss_tests)

    plt.show()
    
    return model

# %%
def generate_data(data, seq_len=50):
    
    chars = list(set(data))
    data_size, vocab_size = len(data), len(chars)
    print 'data has %d characters, %d unique.' % (data_size, vocab_size)
    char_to_ix = { ch:i for i,ch in enumerate(chars) }
    ix_to_char = { i:ch for i,ch in enumerate(chars) }

    d1 = list(data)
    d2 = shuffle_text(d1, 0, len(d1))
    
    l1 = len(d1)/seq_len
    l2 = len(d2)/seq_len
    
    d1.extend(d2)
    
    assert l1 == l2
    
    indices = range(l1+l2)
    random.shuffle(indices)
    
    matrix = np.zeros((l1+l2, seq_len), dtype='int')
    labels = np.zeros(l1+l2, dtype='int')
    
    i = 0
    for k in indices:
        matrix[i, :] = [char_to_ix[c] for c in d1[k:k+seq_len]]
        if k < l1:
            labels[i] = 1
        
        i += 1
    
    p = ((l1+l2)*7)/10
    X_train = matrix[:p,:]
    y_train = labels[:p]
    
    X_test = matrix[p:,:]
    y_test = labels[p:]
    
    return X_train, y_train, X_test, y_test, char_to_ix, ix_to_char, vocab_size

#test for small data, should overfit
data = open('data/warpeace_input.txt','r').read()
data = data[1:500]

X_train, y_train, X_test, y_test, char_to_ix, ix_to_char, vocab_size = generate_data(data)

model = train_model(X_train, y_train, X_test, y_test, vocab_size, 0.0, iters=5, print_every=5, batch_size=50)

print np.mean(model.predict(X_train) == y_train)
# Out:
# data has 499 characters, 45 unique.
# iter 0, loss_train 0.692756, lost_test 0.692743, test accuracy 0.480000
# iter 5, loss_train 0.681156, lost_test 0.687880, test accuracy 0.560000
# 0.916666666667

# %%
#generate data
data = open('data/warpeace_input.txt','r').read()
X_train, y_train, X_test, y_test, char_to_ix, ix_to_char, vocab_size = generate_data(data)

model = train_model(X_train, y_train, X_test, y_test, vocab_size, reg=1e-4, iters=10000, print_every=50, batch_size=50)

print np.mean(model.predict(X_train) == y_train)
# Out:
# data has 3258246 characters, 87 unique.
# iter 0, loss_train 0.693929, lost_test 0.693737, test accuracy 0.440000
# iter 50, loss_train 0.684880, lost_test 0.691675, test accuracy 0.500000
# iter 100, loss_train 0.693119, lost_test 0.693284, test accuracy 0.500000
# iter 150, loss_train 0.695900, lost_test 0.698490, test accuracy 0.480000
# iter 200, loss_train 0.692884, lost_test 0.692261, test accuracy 0.480000
# iter 250, loss_train 0.687944, lost_test 0.697945, test accuracy 0.520000
# iter 300, loss_train 0.694777, lost_test 0.692710, test accuracy 0.540000
# iter 350, loss_train 0.695415, lost_test 0.691815, test accuracy 0.600000
# iter 400, loss_train 0.690751, lost_test 0.681450, test accuracy 0.520000
# iter 450, loss_train 0.687332, lost_test 0.678889, test accuracy 0.600000
# iter 500, loss_train 0.690253, lost_test 0.678303, test accuracy 0.500000
# iter 550, loss_train 0.694169, lost_test 0.697885, test accuracy 0.480000
# iter 600, loss_train 0.693082, lost_test 0.691685, test accuracy 0.580000
# iter 650, loss_train 0.694504, lost_test 0.694119, test accuracy 0.480000
# iter 700, loss_train 0.701888, lost_test 0.697899, test accuracy 0.500000
# iter 750, loss_train 0.707711, lost_test 0.685552, test accuracy 0.580000
# iter 800, loss_train 0.688968, lost_test 0.693101, test accuracy 0.500000
# iter 850, loss_train 0.690316, lost_test 0.687707, test accuracy 0.560000
# iter 900, loss_train 0.715115, lost_test 0.677116, test accuracy 0.600000
# iter 950, loss_train 0.707849, lost_test 0.679478, test accuracy 0.600000
# iter 1000, loss_train 0.702231, lost_test 0.679528, test accuracy 0.600000
# iter 1050, loss_train 0.635417, lost_test 0.702464, test accuracy 0.600000
# iter 1100, loss_train 0.703599, lost_test 0.683078, test accuracy 0.580000
# iter 1150, loss_train 0.664967, lost_test 0.698491, test accuracy 0.500000
# iter 1200, loss_train 0.703307, lost_test 0.624213, test accuracy 0.680000
# iter 1250, loss_train 0.686709, lost_test 0.705609, test accuracy 0.480000
# iter 1300, loss_train 0.643173, lost_test 0.662832, test accuracy 0.600000
# iter 1350, loss_train 0.678257, lost_test 0.645274, test accuracy 0.660000
# iter 1400, loss_train 0.636564, lost_test 0.676101, test accuracy 0.560000
# iter 1450, loss_train 0.563605, lost_test 0.648696, test accuracy 0.600000
# iter 1500, loss_train 0.533589, lost_test 0.678871, test accuracy 0.600000
# iter 1550, loss_train 0.548827, lost_test 0.585201, test accuracy 0.660000
# iter 1600, loss_train 0.591384, lost_test 0.566629, test accuracy 0.720000
# iter 1650, loss_train 0.586540, lost_test 0.651957, test accuracy 0.640000
# iter 1700, loss_train 0.485434, lost_test 0.602543, test accuracy 0.680000
# iter 1750, loss_train 0.553518, lost_test 0.504699, test accuracy 0.760000
# iter 1800, loss_train 0.608454, lost_test 0.540445, test accuracy 0.700000
# iter 1850, loss_train 0.534688, lost_test 0.623875, test accuracy 0.660000
# iter 1900, loss_train 0.556548, lost_test 0.541977, test accuracy 0.760000
# iter 1950, loss_train 0.456032, lost_test 0.455748, test accuracy 0.740000
# iter 2000, loss_train 0.488375, lost_test 0.573489, test accuracy 0.720000
# iter 2050, loss_train 0.563793, lost_test 0.469390, test accuracy 0.820000
# iter 2100, loss_train 0.560375, lost_test 0.546985, test accuracy 0.680000
# iter 2150, loss_train 0.441215, lost_test 0.405391, test accuracy 0.820000
# iter 2200, loss_train 0.483326, lost_test 0.484195, test accuracy 0.840000
# iter 2250, loss_train 0.422429, lost_test 0.438750, test accuracy 0.820000
# iter 2300, loss_train 0.423777, lost_test 0.500127, test accuracy 0.780000
# iter 2350, loss_train 0.418095, lost_test 0.442794, test accuracy 0.780000
# iter 2400, loss_train 0.389715, lost_test 0.313931, test accuracy 0.900000
# iter 2450, loss_train 0.316175, lost_test 0.366079, test accuracy 0.880000
# iter 2500, loss_train 0.434913, lost_test 0.613847, test accuracy 0.700000
# iter 2550, loss_train 0.297870, lost_test 0.340849, test accuracy 0.880000
# iter 2600, loss_train 0.381774, lost_test 0.354553, test accuracy 0.860000
# iter 2650, loss_train 0.291590, lost_test 0.385736, test accuracy 0.840000
# iter 2700, loss_train 0.373789, lost_test 0.371289, test accuracy 0.800000
# iter 2750, loss_train 0.409525, lost_test 0.456856, test accuracy 0.800000
# iter 2800, loss_train 0.342591, lost_test 0.363653, test accuracy 0.860000
# iter 2850, loss_train 0.322169, lost_test 0.309917, test accuracy 0.920000
# iter 2900, loss_train 0.348207, lost_test 0.272413, test accuracy 0.920000
# iter 2950, loss_train 0.185855, lost_test 0.276208, test accuracy 0.880000
# iter 3000, loss_train 0.244939, lost_test 0.352886, test accuracy 0.860000
# iter 3050, loss_train 0.320292, lost_test 0.277550, test accuracy 0.900000
# iter 3100, loss_train 0.209362, lost_test 0.219687, test accuracy 0.940000
# iter 3150, loss_train 0.169343, lost_test 0.218796, test accuracy 0.940000
# iter 3200, loss_train 0.207653, lost_test 0.263113, test accuracy 0.900000
# iter 3250, loss_train 0.296293, lost_test 0.367908, test accuracy 0.860000
# iter 3300, loss_train 0.106485, lost_test 0.239583, test accuracy 0.920000
# iter 3350, loss_train 0.108581, lost_test 0.226302, test accuracy 0.920000
# iter 3400, loss_train 0.252376, lost_test 0.196140, test accuracy 0.940000
# iter 3450, loss_train 0.126487, lost_test 0.262879, test accuracy 0.920000
# iter 3500, loss_train 0.285022, lost_test 0.085540, test accuracy 1.000000
# iter 3550, loss_train 0.136204, lost_test 0.186480, test accuracy 0.960000
# iter 3600, loss_train 0.176442, lost_test 0.153415, test accuracy 0.960000
# iter 3650, loss_train 0.147209, lost_test 0.118085, test accuracy 0.980000
# iter 3700, loss_train 0.121338, lost_test 0.196076, test accuracy 0.940000
# iter 3750, loss_train 0.144344, lost_test 0.119599, test accuracy 0.980000
# iter 3800, loss_train 0.124546, lost_test 0.169166, test accuracy 0.960000
# iter 3850, loss_train 0.319528, lost_test 0.142996, test accuracy 0.960000
# iter 3900, loss_train 0.155844, lost_test 0.167014, test accuracy 0.940000
# iter 3950, loss_train 0.225185, lost_test 0.128405, test accuracy 0.940000
# iter 4000, loss_train 0.094219, lost_test 0.083473, test accuracy 1.000000
# iter 4050, loss_train 0.135391, lost_test 0.170261, test accuracy 0.920000
# iter 4100, loss_train 0.180397, lost_test 0.155289, test accuracy 0.940000
# iter 4150, loss_train 0.128938, lost_test 0.154674, test accuracy 0.940000
# iter 4200, loss_train 0.088427, lost_test 0.387157, test accuracy 0.860000
# iter 4250, loss_train 0.135292, lost_test 0.121208, test accuracy 0.960000
# iter 4300, loss_train 0.194863, lost_test 0.089839, test accuracy 1.000000
# iter 4350, loss_train 0.112851, lost_test 0.149242, test accuracy 0.980000
# iter 4400, loss_train 0.143351, lost_test 0.175854, test accuracy 0.980000
# iter 4450, loss_train 0.079652, lost_test 0.143701, test accuracy 0.980000
# iter 4500, loss_train 0.096509, lost_test 0.090545, test accuracy 0.980000
# iter 4550, loss_train 0.149054, lost_test 0.091353, test accuracy 0.980000
# iter 4600, loss_train 0.073024, lost_test 0.095380, test accuracy 0.980000
# iter 4650, loss_train 0.103185, lost_test 0.071197, test accuracy 1.000000
# iter 4700, loss_train 0.094239, lost_test 0.100350, test accuracy 0.980000
# iter 4750, loss_train 0.209999, lost_test 0.173894, test accuracy 0.940000
# iter 4800, loss_train 0.088616, lost_test 0.251267, test accuracy 0.940000
# iter 4850, loss_train 0.101158, lost_test 0.166394, test accuracy 0.960000
# iter 4900, loss_train 0.149003, lost_test 0.108821, test accuracy 0.980000
# iter 4950, loss_train 0.093547, lost_test 0.131978, test accuracy 0.980000
# iter 5000, loss_train 0.136277, lost_test 0.067886, test accuracy 1.000000
# iter 5050, loss_train 0.118626, lost_test 0.112653, test accuracy 0.960000
# iter 5100, loss_train 0.053555, lost_test 0.171760, test accuracy 0.920000
# iter 5150, loss_train 0.048758, lost_test 0.061256, test accuracy 1.000000
# iter 5200, loss_train 0.141804, lost_test 0.088450, test accuracy 1.000000
# iter 5250, loss_train 0.199179, lost_test 0.088774, test accuracy 0.980000
# iter 5300, loss_train 0.094089, lost_test 0.089106, test accuracy 1.000000
# iter 5350, loss_train 0.064224, lost_test 0.150110, test accuracy 0.960000
# iter 5400, loss_train 0.057465, lost_test 0.058983, test accuracy 1.000000
# iter 5450, loss_train 0.059846, lost_test 0.067841, test accuracy 1.000000
# iter 5500, loss_train 0.074486, lost_test 0.066647, test accuracy 1.000000
# iter 5550, loss_train 0.070933, lost_test 0.145818, test accuracy 0.960000
# iter 5600, loss_train 0.052205, lost_test 0.058106, test accuracy 1.000000
# iter 5650, loss_train 0.070359, lost_test 0.091357, test accuracy 0.960000
# iter 5700, loss_train 0.087763, lost_test 0.225632, test accuracy 0.940000
# iter 5750, loss_train 0.217820, lost_test 0.086459, test accuracy 1.000000
# iter 5800, loss_train 0.172805, lost_test 0.242454, test accuracy 0.960000
# iter 5850, loss_train 0.118570, lost_test 0.122701, test accuracy 0.980000
# iter 5900, loss_train 0.057532, lost_test 0.115940, test accuracy 0.980000
# iter 5950, loss_train 0.102391, lost_test 0.090071, test accuracy 0.980000
# iter 6000, loss_train 0.072753, lost_test 0.055377, test accuracy 1.000000
# iter 6050, loss_train 0.083356, lost_test 0.061419, test accuracy 1.000000
# iter 6100, loss_train 0.076767, lost_test 0.069230, test accuracy 0.980000
# iter 6150, loss_train 0.094983, lost_test 0.057389, test accuracy 1.000000
# iter 6200, loss_train 0.129879, lost_test 0.068154, test accuracy 1.000000
# iter 6250, loss_train 0.054251, lost_test 0.128159, test accuracy 0.980000
# iter 6300, loss_train 0.053919, lost_test 0.093918, test accuracy 0.980000
# iter 6350, loss_train 0.051584, lost_test 0.059269, test accuracy 1.000000
# iter 6400, loss_train 0.070688, lost_test 0.062550, test accuracy 1.000000
# iter 6450, loss_train 0.071607, lost_test 0.071337, test accuracy 0.980000
# iter 6500, loss_train 0.055533, lost_test 0.060091, test accuracy 1.000000
# iter 6550, loss_train 0.052728, lost_test 0.094039, test accuracy 0.960000
# iter 6600, loss_train 0.105014, lost_test 0.069823, test accuracy 1.000000
# iter 6650, loss_train 0.060899, lost_test 0.122766, test accuracy 0.980000
# iter 6700, loss_train 0.180999, lost_test 0.078126, test accuracy 0.980000
# iter 6750, loss_train 0.152545, lost_test 0.154571, test accuracy 0.960000
# iter 6800, loss_train 0.069352, lost_test 0.158534, test accuracy 0.960000
# iter 6850, loss_train 0.096016, lost_test 0.058051, test accuracy 1.000000
# iter 6900, loss_train 0.061618, lost_test 0.070447, test accuracy 1.000000
# iter 6950, loss_train 0.070670, lost_test 0.102339, test accuracy 0.960000
# iter 7000, loss_train 0.060314, lost_test 0.106084, test accuracy 0.980000
# iter 7050, loss_train 0.066619, lost_test 0.057910, test accuracy 1.000000
# iter 7100, loss_train 0.086064, lost_test 0.176098, test accuracy 0.960000
# iter 7150, loss_train 0.287350, lost_test 0.086263, test accuracy 0.980000
# iter 7200, loss_train 0.113136, lost_test 0.081566, test accuracy 1.000000
# iter 7250, loss_train 0.056316, lost_test 0.053615, test accuracy 1.000000
# iter 7300, loss_train 0.096596, lost_test 0.149277, test accuracy 0.940000
# iter 7350, loss_train 0.062038, lost_test 0.076263, test accuracy 1.000000
# iter 7400, loss_train 0.067186, lost_test 0.124656, test accuracy 0.940000
# iter 7450, loss_train 0.078074, lost_test 0.140261, test accuracy 0.960000
# iter 7500, loss_train 0.132246, lost_test 0.204222, test accuracy 0.920000
# iter 7550, loss_train 0.072844, lost_test 0.064608, test accuracy 1.000000
# iter 7600, loss_train 0.064328, lost_test 0.056582, test accuracy 1.000000
# iter 7650, loss_train 0.054257, lost_test 0.068083, test accuracy 1.000000
# iter 7700, loss_train 0.083445, lost_test 0.066870, test accuracy 1.000000
# iter 7750, loss_train 0.157214, lost_test 0.060096, test accuracy 1.000000
# iter 7800, loss_train 0.078790, lost_test 0.053635, test accuracy 1.000000
# iter 7850, loss_train 0.099096, lost_test 0.059106, test accuracy 1.000000
# iter 7900, loss_train 0.096400, lost_test 0.097706, test accuracy 0.980000
# iter 7950, loss_train 0.116914, lost_test 0.052538, test accuracy 1.000000
# iter 8000, loss_train 0.201099, lost_test 0.068639, test accuracy 1.000000
# iter 8050, loss_train 0.063969, lost_test 0.106828, test accuracy 0.980000
# iter 8100, loss_train 0.051789, lost_test 0.067889, test accuracy 1.000000
# iter 8150, loss_train 0.142996, lost_test 0.070111, test accuracy 1.000000
# iter 8200, loss_train 0.052199, lost_test 0.082020, test accuracy 0.980000
# iter 8250, loss_train 0.051675, lost_test 0.054172, test accuracy 1.000000
# iter 8300, loss_train 0.076599, lost_test 0.065222, test accuracy 1.000000
# iter 8350, loss_train 0.138827, lost_test 0.065108, test accuracy 1.000000
# iter 8400, loss_train 0.116026, lost_test 0.068710, test accuracy 1.000000
# iter 8450, loss_train 0.050865, lost_test 0.281803, test accuracy 0.920000
# iter 8500, loss_train 0.058119, lost_test 0.092750, test accuracy 0.960000
# iter 8550, loss_train 0.118745, lost_test 0.152063, test accuracy 0.960000
# iter 8600, loss_train 0.057382, lost_test 0.104151, test accuracy 0.960000
# iter 8650, loss_train 0.064348, lost_test 0.053330, test accuracy 1.000000
# iter 8700, loss_train 0.098944, lost_test 0.113223, test accuracy 0.960000
# iter 8750, loss_train 0.053692, lost_test 0.062488, test accuracy 1.000000
# iter 8800, loss_train 0.053019, lost_test 0.054915, test accuracy 1.000000
# iter 8850, loss_train 0.053383, lost_test 0.052986, test accuracy 1.000000
# iter 8900, loss_train 0.075877, lost_test 0.053433, test accuracy 1.000000
# iter 8950, loss_train 0.054614, lost_test 0.057629, test accuracy 1.000000
# iter 9000, loss_train 0.080527, lost_test 0.096366, test accuracy 0.980000
# iter 9050, loss_train 0.093980, lost_test 0.070673, test accuracy 0.980000
# iter 9100, loss_train 0.072268, lost_test 0.193159, test accuracy 0.960000
# iter 9150, loss_train 0.068280, lost_test 0.118911, test accuracy 0.980000
# iter 9200, loss_train 0.056636, lost_test 0.070537, test accuracy 1.000000
# iter 9250, loss_train 0.071804, lost_test 0.056790, test accuracy 1.000000
# iter 9300, loss_train 0.067395, lost_test 0.101297, test accuracy 0.940000
# iter 9350, loss_train 0.052785, lost_test 0.180269, test accuracy 0.940000
# iter 9400, loss_train 0.060197, lost_test 0.061391, test accuracy 1.000000
# iter 9450, loss_train 0.096919, lost_test 0.132555, test accuracy 0.960000
# iter 9500, loss_train 0.068890, lost_test 0.093118, test accuracy 0.980000
# iter 9550, loss_train 0.052358, lost_test 0.055121, test accuracy 1.000000
# iter 9600, loss_train 0.056889, lost_test 0.087958, test accuracy 0.980000
# iter 9650, loss_train 0.088915, lost_test 0.076043, test accuracy 0.980000
# iter 9700, loss_train 0.052871, lost_test 0.055242, test accuracy 1.000000
# iter 9750, loss_train 0.076710, lost_test 0.059796, test accuracy 1.000000
# iter 9800, loss_train 0.063017, lost_test 0.085425, test accuracy 0.980000
# iter 9850, loss_train 0.066543, lost_test 0.067857, test accuracy 1.000000
# iter 9900, loss_train 0.079338, lost_test 0.150471, test accuracy 0.980000
# iter 9950, loss_train 0.060929, lost_test 0.181575, test accuracy 0.980000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-a410400e1b90> in <module>()
#       5 model = train_model(X_train, y_train, X_test, y_test, vocab_size, reg=1e-4, iters=10000, print_every=50, batch_size=50)
#       6
# ----> 7 print np.mean(model.predict(X_train) == y_train)
#
# /Users/Jarvis/Desktop/Development/ml/experiments/Latent Dirichlet Allocation/MCMC Deciphering/nn/sequence_classifier.py in predict(self, X)
#     126
#     127     def predict(self, X):
# --> 128         scores = self.loss(X)
#     129         return np.argmax(scores, axis=1)
#
# /Users/Jarvis/Desktop/Development/ml/experiments/Latent Dirichlet Allocation/MCMC Deciphering/nn/sequence_classifier.py in loss(self, X, label)
#      79             h0 = np.zeros((N, self.hidden_dims[j]))
#      80
# ---> 81             x, cache['%d'%i] = lstm_forward(x, h0, Wx, Wh, b)
#      82
#      83         ht = x[:,-1,:]
#
# /Users/Jarvis/Desktop/Development/ml/experiments/Latent Dirichlet Allocation/MCMC Deciphering/nn/rnn_layers.pyc in lstm_forward(x, h0, Wx, Wh, b)
#     371   c = np.zeros((N, H))
#     372   for t in xrange(T):
# --> 373     next_h, c, cache[t] = lstm_step_forward(x[:,t,:], h0, c, Wx, Wh, b)
#     374     h[:,t,:] = next_h
#     375     h0 = next_h
#
# /Users/Jarvis/Desktop/Development/ml/experiments/Latent Dirichlet Allocation/MCMC Deciphering/nn/rnn_layers.pyc in lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)
#     271   # You may want to use the numerically stable sigmoid implementation above.  #
#     272   #############################################################################
# --> 273   a = x.dot(Wx) + prev_h.dot(Wh) + b
#     274   i = sigmoid(a[:, :H])
#     275   f = sigmoid(a[:, H:2*H])
#
# KeyboardInterrupt:

# %%
z = model.predict(X_test[:500])
print np.mean(z == y_test[:500])
# Out:
# 0.994

# %%
#default text to work upon
filename = "data/warpeace_input.txt"
t = list(open(filename, 'r').read()[100:200])
i = 0.
cnt = 0.
while i < 100:
    t1 = shuffle_text(t, 50, 100)
    x1 = np.array([[char_to_ix[c] for c in t]], dtype='int')
    x2 = np.array([[char_to_ix[c] for c in t1]], dtype='int')

    l1 = model.log_entropy_wrt_true(x1)
    l2 = model.log_entropy_wrt_true(x2)

    cnt += -l1 > -l2
    i += 1
    
print cnt/i
# Out:
# 0.92

# %%
#time to run monte carlo
i = 20

def compute_probability_using_lstm(state):
    x = np.array([[char_to_ix[c] for c in state["text"]]])
    l = model.log_entropy_wrt_true(x)
    return l

def ps(state):
    return ''.join(state["text"])

initial_state = get_state(t1, None, None, char_to_ix, max_len=i)
state, lps, _ = metropolis_hastings(initial_state, propose_a_move, compute_probability_using_lstm, 
                                  iters=5000, print_every=500, tolerance=0.02, pretty_state=ps)

plt.plot(lps)

plt.show()
# Out:
# Entropy :  -14.6888521207 , Error :  -1 , Acceptance :  0.676589986468
# us  nnl,tsnaoaisy eiaoyeiir ewumtae  fm yi orne rslr d
# l
# Entropy :  -12.0116347118 , Error :  -1 , Acceptance :  0.639386189258
# ura alsrthoeletrinu
#   s eyfwt m fnm
# Entropy :  -13.4376100003 , Error :  -1 , Acceptance :  0.613496932515
# e oi  rrne fseyi  atlm
# unnrtnoaf   mlyf tt
# Entropy :  -11.779016248 , Error :  -1 , Acceptance :  0.684931506849
# Current state : srio i if ea,o  diadumay dtst'eeereprrtneh,rso
# rfyi a
# Entropy :  -13.330289677 , Error :  -1 , Acceptance :  0.582750582751
# Current state : e 'moh,sa ttaao ieu s,de roeiiid ipt oo
# l rrt tahoswdm nslteiyef tt e
# Entropy :  -11.5555514982 , Error :  -1 , Acceptance :  0.599520383693
#  lo l nt umfs
# e sertfy n iira y pi  drdtdtomoreeewr f she ifhylstn
# Entropy :  -10.3527619757 , Error :  -1 , Acceptance :  0.645161290323
# Current state :  ttoit ahene   aoymhu tasr  e
# thf i a'etfs nidt fmpdf nterrew
# Entropy :  -12.3889549962 , Error :  -1 , Acceptance :  0.663129973475
# rnlu  hson i'adif t r,  el nrde  frf wtay sfd
# eimpertrnh
# Entropy :  -14.4962338954 , Error :  -1 , Acceptance :  0.65963060686
# Current state : rhoi,e  ii  tunnl t  oo mdfere iimatlttusetoy',la en r y iysno s atls hndhpfsrmfhr adftow
# d treee
# Entropy :  -13.2364118542 , Error :  -1 , Acceptance :  0.662251655629
# Current state :  ehitry t suhltoefr
# oaoda eey tetl
