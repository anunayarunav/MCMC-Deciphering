# %%
# As usual, a bit of setup

import time
import numpy as np
import matplotlib.pyplot as plt
from metropolis_hastings import *
from deshuffling_utils import *
import sys  

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
filename = "data/warpeace_input.txt"
char_to_ix, ix_to_char, tr, fr = compute_statistics(filename)

filename_2 = "data/shakespeare_input.txt"
char_to_ix_2, ix_to_char_2, tr_2, fr_2 = compute_statistics(filename_2)

# %%
#plot the frequency statistics for characters
fr_stat = {}
fr_stat_2 = {}
chars = list('abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ')
for c in chars:
    fr_stat[c] = fr[char_to_ix[c]]
    fr_stat_2[c] = fr_2[char_to_ix_2[c]]

plt.xticks(xrange(len(fr_stat)), fr_stat.keys())
plt.plot(xrange(len(fr_stat)), fr_stat.values())
plt.plot(xrange(len(fr_stat_2)), fr_stat_2.values())
plt.show()

#strong correlation shows that one of the texts can represent the other text.

# %%
#default text to work upon
t = list(open(filename, 'r').read()[100:200])

t1 = shuffle_text(t, 0, len(t))
print pretty_string(t), '\n',pretty_string(t1)
# Out:
#  if you don't tell me that this means war,
# if you still try to defend the infamies and horrors per...
# oise ns twfemit  loaee dl ttfstn
# hpiaiyre,hhetn as ydrhoeld tmy ui t f n oe ...

# %%
#time to run monte carlo
i = 2

while i < 7:
    initial_state = get_state(t1, tr, fr, char_to_ix, max_len=i)
    state, lps, _ = metropolis_hastings(initial_state, propose_a_move, compute_probability_of_state, 
                                      iters=50000, print_every=50000, tolerance=0.02, pretty_state=pretty_state)

    plt.plot(lps)
    i += 1

plt.show()
# Out:
# Entropy :  244.368684861 , Error :  -1 , Acceptance :  0.634928697507
# lit tiomenes owad s e fone therty, hist p therndy mou
# y hal t t onif de...
# Entropy :  257.082074116 , Error :  -1 , Acceptance :  0.644230273669
# re sines rdit falopltt
# h an th, rito h ay hees ly dedifomey tun t ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-d2af5b633ac0> in <module>()
#       5     initial_state = get_state(t1, tr, fr, char_to_ix, max_len=i)
#       6     state, lps, _ = metropolis_hastings(initial_state, propose_a_move, compute_probability_of_state,
# ----> 7                                       iters=50000, print_every=50000, tolerance=0.02, pretty_state=pretty_state)
#       8
#       9     plt.plot(lps)
#
# /Users/Jarvis/Desktop/Development/ml/experiments/Latent Dirichlet Allocation/MCMC Deciphering/metropolis_hastings.py in metropolis_hastings(initial_state, proposal_function, log_density, iters, print_every, tolerance, error_function, pretty_state)
#      52         #propose a move
#      53         new_state = proposal_function(state)
# ---> 54         p2 = log_density(new_state)
#      55
#      56         u = random.random()
#
# /Users/Jarvis/Desktop/Development/ml/experiments/Latent Dirichlet Allocation/MCMC Deciphering/deshuffling_utils.py in compute_probability_of_state(state)
#      42     """
#      43     p = compute_log_probability_of_text(state["text"], state["char_to_ix"],
# ---> 44                                         state["frequency_statistics"], state["transition_matrix"])
#      45
#      46     return p
#
# /Users/Jarvis/Desktop/Development/ml/experiments/Latent Dirichlet Allocation/MCMC Deciphering/deshuffling_utils.py in compute_log_probability_of_text(text, char_to_ix, frequency_statistics, transition_matrix)
#      31     while i < len(t)-1:
#      32         i1 = cix[t[i+1]]
# ---> 33         p += np.log(tm[i0, i1])
#      34         i0 = i1
#      35         i += 1
#
# KeyboardInterrupt:
